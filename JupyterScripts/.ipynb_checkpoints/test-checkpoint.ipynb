# %% [markdown]
# ## test

# %%
import pandas as pd
import seaborn as sns    
import seaborn.timeseries

summary = pd.read_csv("summary.csv")
summary.head()




def _plot_range_band(*args, central_data=None, ci=None, data=None, **kwargs):
    upper = data.max(axis=0)
    lower = data.min(axis=0)
    #import pdb; pdb.set_trace()
    ci = np.asarray((lower, upper))
    kwargs.update({"central_data": central_data, "ci": ci, "data": data})
    seaborn.timeseries._plot_ci_band(*args, **kwargs)

seaborn.timeseries._plot_range_band = _plot_range_band

#cluster_overload = pd.read_csv("TSplot.csv", delim_whitespace=True)
#cluster_overload['Unit'] = cluster_overload.groupby(['Cluster','Week']).cumcount()

ax = sns.lineplot(time='transfer_n',value="count", data=summary,
               err_style="range_band", n_boot=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/seaborn/relational.py in establish_variables(self, x, y, hue, size, style, units, data)
#      60                 try:
# ---> 61                     data.astype(np.float)
#      62                 except ValueError:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5545             # else, only a single dtype is given
# -> 5546             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5547             return self._constructor(new_data).__finalize__(self, method="astype")
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     594     ) -> "BlockManager":
# --> 595         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
# ...

# %%
# Out:
#       Unnamed: 0 transfer_n  replicate      strategy phenotype   fraction  \
# 0              0         t0        0.0         Combo       A_r   6.250000
# 1              1         t0        0.0         Combo       B_r   4.166667
# 2              2         t0        0.0         Combo        UI  13.541667
# 3              3         t0        0.0         Combo        WT  76.041667
# 4              4         t0        0.0       Cycling       A_r   5.208333
# ...          ...        ...        ...           ...       ...        ...
# 1449        1449        t18        3.0  No treatment       A_r  30.208333
# 1450        1450        t18        3.0  No treatment       B_r   5.208333
# 1451        1451        t18        3.0  No treatment     Fishy   1.041667
# 1452        1452        t18        3.0  No treatment        UI   4.166667
# 1453        1453        t18        3.0  No treatment        WT  29.166667
#
#       contaminated  exclude  infected_by_strains  infected_by_wells  ...  \
# ...

# %%
P_ex = [6]
t_ex = [9]

exclude = pd.DataFrame(P_ex, columns = ["P_ex"])
exclude["t_ex"] = t_ex

exclude.to_csv("exclude_plates.csv", index_label=False)

# %%
pd.DataFrame(P_ex).to_csv("exclude_plate.csv")
pd.DataFrame(t_ex).to_csv("exclude_transfer.csv")
