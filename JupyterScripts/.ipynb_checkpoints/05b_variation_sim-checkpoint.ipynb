# %%
# %load_ext autoreload
# %autoreload 2

from model_scripts.simulation_bundle import Simulation_bundle
from model_scripts.instrutcion_set_class import InstructionSet

# %%
experiments = ["20210417", "20220127", "20220412"]

date = "20220412"

# %%
for date in experiments:
    print("\n", date)
    simulations = Simulation_bundle(date)
    simulations.variation(5)
    simulations.save_timeplot("var_sim.pkl")
# Out:
#  20210417
# var:  0
# var:  1
# var:  2
# var:  3
# var:  4
#
#  20220127
# var:  0
# var:  1
# var:  2
# var:  3
# var:  4
#
#  20220412
# var:  0
# var:  1
# var:  2
# var:  3
# var:  4

# %%
simulations.quickplot()
