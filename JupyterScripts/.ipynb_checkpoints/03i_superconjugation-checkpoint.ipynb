# %% [markdown]
# ## Special Skript for the 20220412 Emergence Experiment

# %%
# %load_ext autoreload
# %autoreload 2
from evaluation_scripts.experiment_class import Experiment
from evaluation_scripts.superconjugation_class import Superconjugation
from evaluation_scripts.style import Style
import matplotlib.pyplot as plt
from evaluation_scripts.oneway import OneWaySignificance
import os

# %%
style = Style(fontsize = 20, figsize = (12,6))
dark_style = Style("black", figsize = (12, 6))

# %%
exp = "20220412"
alpha = .05
experiment = Experiment(exp)

# %%
exp = "20220412"
alpha = .05
experiment = Experiment(exp)
superconjugation = Superconjugation(experiment)
superconjugation.emergence_per_encounter()
superconjugation.encounter_frequencies()

# %% [markdown]
# ## Superinfections

# %%
fig, ax = style.create_figure_with_style()
superinfections = OneWaySignificance(superconjugation.superinfections, "strategy", "f")
ax = superinfections.plot(order = experiment.strategies, strip = True, dot_color = "grey", ax = ax, jitter = 0.1)
ax.set_xlabel("strategies")  
ax.set_ylabel(r"superinfections per patient $n_\mathcal{S}/n_P$") 
experiment.save_figure("encounter_frequencies.pdf")
superinfections.write_anova_results(os.path.join(experiment.pathes["tables"], "superinfection_anova.tex"))
superinfections.write_tukey_results(os.path.join(experiment.pathes["tables"], "superinfection_tukey.tex"))

# %%
import seaborn as sns
palette = sns.color_palette("pastel")
palette
# Out:
# [(0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  (1.0, 0.7058823529411765, 0.5098039215686274),
#  (0.5529411764705883, 0.8980392156862745, 0.6313725490196078),
#  (1.0, 0.6235294117647059, 0.6078431372549019),
#  (0.8156862745098039, 0.7333333333333333, 1.0),
#  (0.8705882352941177, 0.7333333333333333, 0.6078431372549019),
#  (0.9803921568627451, 0.6901960784313725, 0.8941176470588236),
#  (0.8117647058823529, 0.8117647058823529, 0.8117647058823529),
#  (1.0, 0.996078431372549, 0.6392156862745098),
#  (0.7254901960784313, 0.9490196078431372, 0.9411764705882353)]

# %%
sns.color_palette("Paired")
# Out:
# [(0.6509803921568628, 0.807843137254902, 0.8901960784313725),
#  (0.12156862745098039, 0.47058823529411764, 0.7058823529411765),
#  (0.6980392156862745, 0.8745098039215686, 0.5411764705882353),
#  (0.2, 0.6274509803921569, 0.17254901960784313),
#  (0.984313725490196, 0.6039215686274509, 0.6),
#  (0.8901960784313725, 0.10196078431372549, 0.10980392156862745),
#  (0.9921568627450981, 0.7490196078431373, 0.43529411764705883),
#  (1.0, 0.4980392156862745, 0.0),
#  (0.792156862745098, 0.6980392156862745, 0.8392156862745098),
#  (0.41568627450980394, 0.23921568627450981, 0.6039215686274509),
#  (1.0, 1.0, 0.6),
#  (0.6941176470588235, 0.34901960784313724, 0.1568627450980392)]

# %%
styles["presentation"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 styles["presentation"]
#
# NameError: name 'styles' is not defined

# %%
from figures import Figure, styles
presentation = Figure(styles["presentation"])
presentation.add_folder("/Users/malte/Documents/Meetings/Smiddy")
# Out:
# {'rcParams': {'text.usetex': True,
#   'font.family': 'serif',
#   'font.size': 32,
#   'axes.labelsize': 32,
#   'axes.titlesize': 40.0,
#   'xtick.labelsize': 24.0,
#   'ytick.labelsize': 24.0,
#   'legend.fontsize': 24.0,
#   'figure.figsize': (6, 4),
#   'figure.dpi': 300,
#   'savefig.dpi': 300,
#   'xtick.direction': 'out',
#   'ytick.direction': 'out',
#   'axes.linewidth': 0.5,
#   'xtick.major.width': 0.5,
#   'ytick.major.width': 0.5,
#   'axes.edgecolor': 'white',
#   'axes.labelcolor': 'white',
#   'xtick.color': 'white',
#   'ytick.color': 'white',
#   'text.color': 'white',
#   'axes.facecolor': 'black',
#   'figure.facecolor': 'black',
#   'figure.edgecolor': 'white',
#   'savefig.facecolor': 'black',
#   'savefig.edgecolor': 'white'},
#  'frame': {'top': True,
#   'right': True,
#   'left': True,
#   'bottom': True,
#   'left_position': ('outward', 0),
#   'bottom_position': ('outward', 0),
#   'yticks_position': 'left',
#   'xticks_position': 'bottom',
#   'show_ticks': True,
#   'show_tick_labels': True},
#  'labelpad': {'xlabelpad': 40, 'ylabelpad': 40}}

# %%
fig, ax = presentation.create_figure_with_style(figsize = (16,8))

superinfections = OneWaySignificance(superconjugation.superinfections, "strategy", "f")
ax = superinfections.plot(order = experiment.strategies, strip = True, dot_color = "white", ax = ax, jitter = 0.1, bar_color=palette[-2], violin = False)
ax.set_xlabel(None)  
ax.set_ylabel(r"superinfections per patient") 
#plt.savefig("f_superinfection.png", dpi = 300)
presentation.save_figure("f_superinfection")
plt.show()
# Out:
# Figure saved at /Users/malte/Documents/Meetings/Smiddy/f_superinfection.pdf

# %% [markdown]
# ## emergence per encounter
# - each dot represents all wells treated with x on a plate

# %%
fig, ax = style.create_figure_with_style(figsize = (6,6))
emergence = OneWaySignificance(superconjugation.emergence_summary, "treatment_with", "f")
ax = emergence.plot( 
    dot_color = "grey", 
    order = ["none", "A", "B", "AB"], 
    order_col = "treatment_with", 
    ax = ax,
    strip = True,
    jitter = .2)
ax.set_xlabel(r"treatment")  
ax.set_ylabel(r"emergence per superinfec. $n_\mathcal{E}/n_\mathcal{S}$") 
experiment.save_figure("conjugation_prop.pdf")
emergence.write_anova_results(os.path.join(experiment.pathes["tables"], "treatment_emergence_anova.tex"))
emergence.write_tukey_results(os.path.join(experiment.pathes["tables"], "treatment_emergence_tukey.tex"))
plt.show()

# %%
_, ax = presentation.create_figure_with_style(figsize = (8,8))
emergence = OneWaySignificance(superconjugation.emergence_summary, "treatment_with", "f")
ax = emergence.plot( 
    dot_color = "white", 
    order = ["none", "A", "B", "AB"], 
    order_col = "treatment_with", 
    ax = ax,
    strip = True,
    jitter = .2,
    violin = False, 
    bar_color = sns.color_palette("Paired")[4])
ax.set_xlabel(r"treatment")  
ax.set_ylabel(r"emergence per superinfection") 
presentation.save_figure("emergence_per_superinfection")
plt.show()
# Out:
# Figure saved at /Users/malte/Documents/Meetings/Smiddy/emergence_per_superinfection.pdf

# %% [markdown]
# ## Create Expectations

# %%
superconjugation.calculate_expected_frequencies()
experiment.pickle_df(superconjugation.expectations, "expectations_emergence.pkl")
superconjugation.expectations
# Out:
#                      f
# No treatment  0.068075
# Mono A        0.003213
# Mono B        0.025131
# Mixing        0.018244
# Combination   0.000000
# Cycling       0.011407
